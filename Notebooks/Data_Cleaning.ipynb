# %% [markdown]
# ## 0. Introduction
# this notebook shows the data Cleaning steps and ft. eng.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_churn = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df_churn.shape)
print(df_churn['customerID'].is_unique)
print(df_churn['customerID'].duplicated().sum())
print(df_churn.dtypes)
# Out:
# (7043, 21)
# True
# 0
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# #### Demographic info about customers:
#
# * gender – Customer’s gender (Male/Female).
# * SeniorCitizen – Whether the customer is a senior (1) or not (0).
# * Partner – Whether the customer has a partner (Yes/No).
# * Dependents – Whether the customer has dependents (children or others).
#
# #### Customer account information
#
# * tenure – Number of months the customer has been with the company.
# * Contract – Type of contract (Month-to-month, One year, Two year).
# * PaperlessBilling – Whether billing is paperless (Yes/No).
# * PaymentMethod – Method used for payments (electronic check, mailed check, etc.).
# * MonthlyCharges – Monthly amount charged to the customer.
# * TotalCharges – Total amount paid by the customer over their entire tenure.
#
# #### Services that each customer has signed up for
#
# * PhoneService – Whether the customer has phone service.
# * MultipleLines – Whether they have multiple phone lines.
# * InternetService – Type of internet service (DSL, Fiber optic, None).
# * OnlineSecurity – Whether online security add-on is enabled.
# * OnlineBackup – Whether cloud backup service is enabled.
# * DeviceProtection – Whether device protection plan is subscribed.
# * TechSupport – Whether technical support add-on is enabled.
# * StreamingTV – Whether streaming TV service is active.
# * StreamingMovies – Whether streaming movies service is active.
#
# #### Customer ID
#
# * customerID
#
#
# #### Customers who left within the last month (our target)
# * Churn

# %%
# most of the features is categorical
# =====> TotalCharges "object" expext "float64" as MonthlyCharges
# found empty strings in it ' ' 
df_churn[df_churn['TotalCharges']==" "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df_churn.loc[df_churn['tenure'] == 0]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
# clients with tenure = 0 => just started the contract => TotalCharges no payments yet
df_churn.loc[df_churn['TotalCharges']==" ", ['customerID', 'tenure', 'MonthlyCharges', 'TotalCharges' ]]
# Out:
#       customerID  tenure  MonthlyCharges TotalCharges
# 488   4472-LVYGI       0           52.55
# 753   3115-CZMZD       0           20.25
# 936   5709-LVOEQ       0           80.85
# 1082  4367-NUYAO       0           25.75
# 1340  1371-DWPAZ       0           56.05
# 3331  7644-OMVMY       0           19.85
# 3826  3213-VVOLG       0           25.35
# 4380  2520-SGTTA       0           20.00
# 5218  2923-ARZLG       0           19.70
# 6670  4075-WKNIU       0           73.35
# 6754  2775-SEFEE       0           61.90

# %% [markdown]
# ##### TotalCharges to float all empty fields

# %%
df_churn['TotalCharges'] = df_churn['TotalCharges'].replace(" ", np.nan)
df_churn['TotalCharges'] = pd.to_numeric(df_churn['TotalCharges'])
df_churn['TotalCharges'].isna().sum()
df_churn.loc[df_churn['tenure']==0, ['customerID', 'tenure', 'MonthlyCharges', 'TotalCharges' ]]
# Out:
#       customerID  tenure  MonthlyCharges  TotalCharges
# 488   4472-LVYGI       0           52.55           NaN
# 753   3115-CZMZD       0           20.25           NaN
# 936   5709-LVOEQ       0           80.85           NaN
# 1082  4367-NUYAO       0           25.75           NaN
# 1340  1371-DWPAZ       0           56.05           NaN
# 3331  7644-OMVMY       0           19.85           NaN
# 3826  3213-VVOLG       0           25.35           NaN
# 4380  2520-SGTTA       0           20.00           NaN
# 5218  2923-ARZLG       0           19.70           NaN
# 6670  4075-WKNIU       0           73.35           NaN
# 6754  2775-SEFEE       0           61.90           NaN

# %%
# we can drop them cause they just started using the service

print(df_churn.shape)
# we drom 11 raws
df_churn = df_churn.dropna(subset=['TotalCharges'])

# drop customerID, meaningless for predictions
df_churn = df_churn.drop(columns=['customerID'])

print(df_churn.shape)

df_churn.isna().sum()
# Out:
# (7043, 21)
# (7032, 20)
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_churn.duplicated().sum()
df_churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ### Convert some categorical feature to numerical

# %%
df_churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
for c in df_churn.columns:
    print(c)
    print(df_churn[c].unique(), '\n')
# Out:
# gender
# ['Female' 'Male']
#
# SeniorCitizen
# [0 1]
#
# Partner
# ['Yes' 'No']
#
# Dependents
# ['No' 'Yes']
#
# tenure
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
#
# PhoneService
# ['No' 'Yes']
#
# MultipleLines
# ['No phone service' 'No' 'Yes']
#
# InternetService
# ['DSL' 'Fiber optic' 'No']
#
# OnlineSecurity
# ['No' 'Yes' 'No internet service']
#
# OnlineBackup
# ['Yes' 'No' 'No internet service']
#
# DeviceProtection
# ['No' 'Yes' 'No internet service']
#
# TechSupport
# ['No' 'Yes' 'No internet service']
#
# StreamingTV
# ['No' 'Yes' 'No internet service']
#
# StreamingMovies
# ['No' 'Yes' 'No internet service']
#
# Contract
# ['Month-to-month' 'One year' 'Two year']
#
# PaperlessBilling
# ['Yes' 'No']
#
# PaymentMethod
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
# ...

# %%
df_churn['gender'] = df_churn['gender'].map({'Female': 0, 'Male': 1})
df_churn['Partner'] = df_churn['Partner'].map({'No': 0, 'Yes': 1})
df_churn['Dependents'] = df_churn['Dependents'].map({'No': 0, 'Yes': 1})
df_churn['PhoneService'] = df_churn['PhoneService'].map({'No': 0, 'Yes': 1})
df_churn['PaperlessBilling'] = df_churn['PaperlessBilling'].map({'No': 0, 'Yes': 1})

df_churn['Churn'] = df_churn['Churn'].map({'No': 0, 'Yes': 1})

# %%
df_churn.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_churn.to_csv("../data/cleaned_telecom_churn_data.csv", index=False)
